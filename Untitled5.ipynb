# %%
my_list=[1,2,3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list[0]
# Out:
# 1

# %%
my_list=[1,'hello',45,67,89,'bye']

# %%
len(my_list)
# Out:
# 6

# %%
my_list[2:4]
# Out:
# [45, 67]

# %%
|my_list[0:]
# Out:
#   File "<ipython-input-8-3f1b604cf503>", line 1
#     |my_list[0:]
#     ^
# SyntaxError: invalid syntax

# %%
my_list[1:]
# Out:
# ['hello', 45, 67, 89, 'bye']

# %%
my_list=my_list+['new item']

# %%
my_list
# Out:
# [1, 'hello', 45, 67, 89, 'bye', 'new item']

# %%
my_list*3
# Out:
# [1,
#  'hello',
#  45,
#  67,
#  89,
#  'bye',
#  'new item',
#  1,
#  'hello',
#  45,
#  67,
#  89,
#  'bye',
#  'new item',
#  1,
#  'hello',
#  45,
#  67,
#  89,
#  'bye',
#  'new item']

# %%
list1=[1,2,3]

# %%
list1.append('append me!')

# %%
list1
# Out:
# [1, 2, 3, 'append me!']

# %%
list1.pop(0)
# Out:
# 1

# %%
list1
# Out:
# [2, 3, 'append me!']

# %%
new_list=['a','e','i','o','u']

# %%
new_list
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
new_list.reverse()

# %%
new_list
# Out:
# ['u', 'o', 'i', 'e', 'a']

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'e', 'i', 'o', 'u']

# %%
list2=[2,55,44,32,19]

# %%
max(list2)
# Out:
# 55

# %% [markdown]
# min(list2)

# %%
min(list2)
# Out:
# 2

# %%
list2.sort()

# %%
list4
# Out:
# [2, 19, 32, 44, 55]

# %%
lst_1=[1,2,3]

# %%
lst_2= [4,5,6]

# %%
lst_3=[7,8,9]

# %%
matrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-36a5fe1d79ae> in <module>
# ----> 1 matrix
#
# NameError: name 'matrix' is not defined

# %%
matrix = [lst_1,lst_2,lst_3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-b1ba15b1b577> in <module>
# ----> 1 matrix = [lst_1,lst_2,lst_3]
#
# NameError: name 'lst_2' is not defined

# %%
lst_1=[1,2,3]
lst_2=[4,5,6]
lst_3=[7,8,9]

# %%
matrix=[lst_1,lst_2,lst_3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-f1ef154097f9> in <module>
# ----> 1 matrix=[lst_1,lst_2,lst_3]
#
# NameError: name 'lst_2' is not defined

# %%
first_col = [row[0] for row in matrix]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-e9d79f980a6c> in <module>
# ----> 1 first_col = [row[0] for row in matrix]
#
# NameError: name 'matrix' is not defined
